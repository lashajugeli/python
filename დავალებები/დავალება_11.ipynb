# %%
# 11.1

def average_temperature(temps):
    return sum(temps) / len(temps)

def main():
    temps = [22, 25, 19, 23, 25, 26, 23]
    avg = average_temperature(temps)
    print(f"Average temperature is {avg:.2f}°C")

if __name__ == "__main__":
    main()
# Out:
# Average temperature is 23.29°C

# %%
#11.2

import random

def generate_random_list(count, low, high):
    nums = []
    for _ in range(count):
        nums.append(random.randint(low, high))
    return nums

def expand_list_by_value(nums):
    expanded = []
    for n in nums:
        expanded.extend([n] * n)
    return expanded

def main():
    original = generate_random_list(50, 1, 30)
    print("Original list:", original)

    expanded = expand_list_by_value(original)
    print("Expanded list:", expanded)

    print("Length of expanded list:", len(expanded))

if __name__ == "__main__":
    main()
# Out:
# Original list: [9, 13, 24, 3, 10, 14, 2, 20, 6, 23, 28, 21, 19, 29, 27, 14, 14, 4, 16, 25, 4, 14, 10, 2, 14, 19, 4, 6, 11, 24, 13, 25, 17, 30, 13, 14, 23, 25, 9, 20, 6, 2, 26, 19, 12, 8, 10, 21, 9, 20]
# ...
