# %%
# 11.1

def average_temperature(temps):
    return sum(temps) / len(temps)

def main():
    temps = [22, 25, 19, 23, 25, 26, 23]
    avg = average_temperature(temps)
    print(f"Average temperature is {avg:.2f}°C")

if __name__ == "__main__":
    main()
# Out:
# Average temperature is 23.29°C

# %%
#11.2

import random

def expand_list_by_value(nums):
    expanded = []
    for n in nums:
        expanded.extend([n] * n)
    return expanded

def generate_expanded_random_list(count, low, high):
    nums = []
    for _ in range(count):
        nums.append(random.randint(low, high))
    return expand_list_by_value(nums)

def main():
    expanded_list = generate_expanded_random_list(50, 1, 30)
    print("Expanded list:", expanded_list)

    print("Length of expanded list:", len(expanded_list))

if __name__ == "__main__":
    main()
# Out:
# Expanded list: [3, 3, 3, 2, 2, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 9, 9, 9, 9, 9, 9, 9, 9, 9, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 7, 7, 7, 7, 7, 7, 7, 2, 2, 9, 9, 9, 9, 9, 9, 9, 9, 9, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 7, 7, 7, 7, 7, 7, 7, 1, 9, 9, 9, 9, 9, 9, 9, 9, 9, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 5, 5, 5, 5, 5, 
# ...

# %%
# 11.3

import random

numbers = []
for _ in range(50):
    numbers.append(random.randint(1, 30))

unique = []
for n in numbers:
    if n not in unique:
        unique.append(n)

print("List -", unique)
print("Length -", len(unique))
# Out:
# List - [20, 21, 23, 9, 2, 8, 24, 12, 25, 13, 28, 11, 16, 26, 30, 22, 3, 27, 5, 19, 10, 15]
# Length - 22
