# %%
# 12.1

from random import randint

random_numbers = [randint(10, 1000000000) for _ in range(100)]

shortest = min(random_numbers, key=lambda x: len(str(x)))
longest = max(random_numbers, key=lambda x: len(str(x)))

sorted_asc = sorted(random_numbers, key=lambda x: len(str(x)))

sorted_desc = sorted(random_numbers, key=lambda x: len(str(x)), reverse=True)

print("ყველაზე მოკლე რიცხვი:", shortest)
print("ყველაზე გრძელი რიცხვი:", longest)

print("დალაგებული ზრდადობით:")
print(sorted_asc)

print("დალაგებული კლებადობით:")
print(sorted_desc)
# Out:
# ყველაზე მოკლე რიცხვი: 6962525
# ყველაზე გრძელი რიცხვი: 945987464
# დალაგებული ზრდადობით:
# ...

# %%
# 12.2

from random import randint

list_len = 10

list1 = [randint(1, 100) for _ in range(list_len)]
list2 = [randint(1, 100) for _ in range(list_len)]
list3 = [randint(1, 100) for _ in range(list_len)]

list_sum = [list1[i] + list2[i] + list3[i] for i in range(list_len)]

print("სია 1:", list1)
print("სია 2:", list2)
print("სია 3:", list3)

print("სიების ჯამი:", list_sum)
# Out:
# სია 1: [87, 79, 58, 2, 52, 72, 26, 34, 98, 16]
# სია 2: [67, 40, 28, 43, 56, 13, 78, 89, 77, 66]
# სია 3: [34, 24, 39, 85, 79, 26, 74, 9, 56, 35]
# სიების ჯამი: [188, 143, 125, 130, 187, 111, 178, 132, 231, 117]
